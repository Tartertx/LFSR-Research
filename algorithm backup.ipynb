# %% [markdown]
# Copyright Tarter, Herasymov, Priebracha 2025

# %%
import pandas as pd 
import numpy as np 
import math 
import random as rd
import warnings
import time
warnings.filterwarnings('ignore')

def genRec(length): #generate the recurrence for the test case
    rec = ''
    for i in range(length):
        rec += f'{rd.randint(0,1)}'
    return rec

def genSeq(slength, rlength): #generate the full sequence for the test case
    seq = ''
    rec = genRec(rlength)
    for i in range(slength):
        seq += rec
    return seq, rec, 0, 0, 0

digitLength = 1000
sampleSize = 250

tests = pd.DataFrame(columns=['Test Case', 'Reccurence', 'Solution', 'Works?', 'Time']) #initialize the dataframe
for k in range(sampleSize): #generate the test cases
    tests.loc[k] = genSeq(5,digitLength)


testList = tests['Test Case'].to_list() #send each test case to a list

def decode(sequence):
    n = len(sequence) #get length
    factors = []
    for j in range(n-2): #find factors
        if n % (j+2) == 0:
            factors += [n/(j+2)]
    
    mFact = max(factors) #pick the largest factor
    rec = sequence[int(n - mFact + 2):n] #isolate the recurrence
    return rec, int(n-mFact+2), n


l = 0
for sequence in testList:
    start = time.time()
    tests.loc[l,'Solution'], repets, n = decode(sequence)
    end = time.time()

    tests.loc[l,'Time'] = round(end - start,8)#log time for complexity

    if str(tests.loc[l,'Test Case'])[repets:n] == tests.loc[l,'Solution']: #checks our work
        tests.loc[l,'Works?'] = 1
    
    l += 1


display(tests)
print(f'Mean time for {digitLength} bits and {sampleSize} samples is {np.mean(tests['Time'])}.')
# Out:
#                                              Test Case  \
# 0    1000011110011010100100100100100011100011111001...
# 1    1010010101001000001000101101001011111100100001...
# 2    0101001111101110010101001111011010111111001101...
# 3    0111100110100110001011000001001110101000011001...
# 4    0000110111010010001011011101110110100010111101...
# ..                                                 ...
# 245  0101100111010001011100010101000110011010101110...
# 246  0011110111101101101001000010001110101110110110...
# 247  0110101000011001000011110100000010100001100011...
# 248  0110100001000110111001100011111001110000101011...
# 249  0100111100011110111000010000010111100010000010...
#
#                                             Reccurence  \
# 0    1000011110011010100100100100100011100011111001...
# 1    1010010101001000001000101101001011111100100001...
# 2    0101001111101110010101001111011010111111001101...
# 3    0111100110100110001011000001001110101000011001...
# ...
