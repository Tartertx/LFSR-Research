# %% [markdown]
# Makes test cases:

# %%
import pandas as pd 
import numpy as np 
import math 
import random as rd
import warnings
import time
warnings.filterwarnings('ignore')

def genRec(length): #generate the recurrence for the test case
    rec = ''
    for i in range(length):
        rec += f'{rd.randint(0,1)}'
    return rec

def genSeq(slength, rlength): #generate the full sequence for the test case
    seq = ''
    rec = genRec(rlength)
    for i in range(slength):
        seq += rec
    return seq, rec, 0, 0, 0

digitLength = 100000
sampleSize = 1000

tests = pd.DataFrame(columns=['Test Case', 'Reccurence', 'Solution', 'Works?', 'Time']) #initialize the dataframe
for k in range(sampleSize): #generate the test cases
    tests.loc[k] = genSeq(5,digitLength)

# %% [markdown]
# Decode and test:

# %%
testList = tests['Test Case'].to_list() #send each test case to a list

def decode(sequence):
    n = len(sequence) #get length
    factors = []
    for j in range(n-2): #find factors
        if n % (j+2) == 0:
            factors += [n/(j+2)]
    
    mFact = max(factors) #pick the largest factor
    rec = sequence[int(n - mFact + 2):n] #isolate the recurrence
    return rec, int(n-mFact+2), n


l = 0
for sequence in testList:
    start = time.time()
    tests.loc[l,'Solution'], repets, n = decode(sequence)
    end = time.time()

    tests.loc[l,'Time'] = round(end - start,8)#log time for complexity

    if str(tests.loc[l,'Test Case'])[repets:n] == tests.loc[l,'Solution']: #checks our work
        tests.loc[l,'Works?'] = 1
    
    l += 1


display(tests)
print(f'Mean time for {digitLength} bits and {sampleSize} samples is {np.mean(tests['Time'])}.')
# Out:
#                                              Test Case  \
# 0    1001101010110101110110000111101010100001011101...
# 1    1000111010101010000010011101010010111010110001...
# 2    0101010011110110100111111010011111010101110001...
# 3    1010011010010011110100001100000101100001111001...
# 4    0001111101111111101110011000110001000010010111...
# ..                                                 ...
# 995  1111011011111000101011000010011011111010001101...
# 996  1011000011001010001001011110100011011001000000...
# 997  1000000100111101110001011000111000001000000111...
# 998  0100100111100101101010100010101111100100011101...
# 999  1010011100010101000110101001010011000000101100...
#
#                                             Reccurence  \
# 0    1001101010110101110110000111101010100001011101...
# 1    1000111010101010000010011101010010111010110001...
# 2    0101010011110110100111111010011111010101110001...
# 3    1010011010010011110100001100000101100001111001...
# 4    0001111101111111101110011000110001000010010111...
# ..                                                 ...
# 995  1111011011111000101011000010011011111010001101...
# 996  1011000011001010001001011110100011011001000000...
# 997  1000000100111101110001011000111000001000000111...
# 998  0100100111100101101010100010101111100100011101...
# 999  1010011100010101000110101001010011000000101100...
#
#                                               Solution  Works?      Time
# 0    1100001100111011000111110111100010111100101100...       1  0.004995
# 1    1110010000111101010010000011101011101110100100...       1  0.005002
# 2    1000000111111010001100111100110000000111011010...       1  0.003997
# 3    0101001110111001001110000010101101101111010010...       1  0.003998
# 4    1011000010100010111111010110000011011000001100...       1  0.004001
# ..                                                 ...     ...       ...
# 995  1101111001110100000110100100110011010110001011...       1  0.004884
# 996  1111011011101101110101111001101011110001101000...       1  0.005582
# 997  1001101011011100111100000111110101010011010111...       1  0.004739
# 998  1110100100010100011010010001001000001111000110...       1  0.005292
# 999  1010010001100111000101001010100100000000101001...       1  0.004676
#
# [1000 rows x 5 columns]
# Mean time for 10000 bits and 1000 samples is 0.0044468352.
